# %%
# !pip install datasets
# !pip install lightning
# !pip install pycocoevalcap
# !pip install -r /kaggle/input/mamba-files/mamba-main/requirements.txt
# !pip install -U pytorch-lightning
# !pip install einops
# !pip install python-multipart==0.0.9
# !pip install google-auth==2.22.0
# !pip install google-api-python-client==2.97.0
# !pip install apiclient
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.0/811.0 kB 14.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 15.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.8/427.8 kB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 9.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 25.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 kB 6.8 MB/s eta 0:00:00
# ...

# %%
import shutil
import os
import torch 

if os.path.exists("/kaggle/working/checkMamba"):
    shutil.rmtree("/kaggle/working/checkMamba")
shutil.copytree(src="/kaggle/input/checkmamba",dst="/kaggle/working/checkMamba")
# shutil.copytree(src="/kaggle/input/checkpth122",dst="/kaggle/working/checkpoints")


# new_ckpt = torch.load("/kaggle/input/checkpth122/checkpoint_epoch0_step327_bleu0.000000_cider0.000000.pth")
# new_ckpt["pytorch-lightning_version"] = "1.9.0"
# new_ckpt["state_dict"] = new_ckpt["model"]
# torch.save(new_ckpt, f"/kaggle/working/fixed_model_state.pth")
# new_ckpt.keys()
# Out:
# '/kaggle/working/checkMamba'

# %%
# x = torch.load("/kaggle/input/checkpth122/checkpoint_epoch0_step0_bleu0.000000_cider0.000000 (1).pth")
# y = torch.load("/kaggle/input/checkpth122/checkpoint_epoch0_step0_bleu0.000000_cider0.000000.pth")
# z = torch.load("/kaggle/input/checkpth122/checkpoint_epoch0_step122_bleu0.000000_cider0.000000.pth")
# for i in new_ckpt["model"].keys():
#     if new_ckpt["model"][i].shape!=y["model"][i].shape:
#         print(new_ckpt["model"][i].shape,y["model"][i].shape,z["model"][i].shape,x["model"][i].shape)

# %%
# !mkdir FSDP

# %%
# !python "checkMamba/checkMambaK.py"
# Out:
# /kaggle/input/mamba-files/mamba-main/classification/models/csms6s.py:13: UserWarning: Can not import selective_scan_cuda_oflex. This affects speed.
#   warnings.warn("Can not import selective_scan_cuda_oflex. This affects speed.")
# Can not import selective_scan_cuda_oflex. This affects speed.
# /kaggle/input/mamba-files/mamba-main/classification/models/csms6s.py:74: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, u, delta, A, B, C, D=None, delta_bias=None, delta_softplus=False, oflex=True, backend=None):
# /kaggle/input/mamba-files/mamba-main/classification/models/csms6s.py:91: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dout, *args):
# ...
